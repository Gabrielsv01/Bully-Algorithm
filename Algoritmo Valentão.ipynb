# %%
class Processo():
    def __init__(self, id_Processo , is_Coordenador = False, is_Ativo = True):
        self.identificador = id_Processo
        self.coordenador = is_Coordenador
        self.ativo = is_Ativo
        self.qualCoord = "null"
    
    def Eleicao(self):
        for c in enderecos_processos:
            
            if (c.Identificador() > self.identificador) :
                if (c.Is_Ativo() == True):
                    if (c.identificador != self.identificador):
                        text = "O processo com ID: {} saiu da eleição.".format(self.identificador)
                    self.coordenador = False
                    print(text) 
                    c.Eleicao()
                    break

                if ((c.Is_Ativo() == False) and c.Is_Coordenador()):
                    self.coordenador = True
                    enderecos_processos[self.identificador-1].Verifica_coordenador()
                    print("\nO processo: {} é o novo Coordenador(Valentão)\n".format(self.identificador))
            
            if(c.Is_Ativo() and c.Is_Coordenador()):
                print("\nO processo: {} é o novo Coordenador(Valentão)\n".format(self.identificador))

    ### Funções de retorno de valores de processos
    def Is_Ativo(self):
        return self.ativo
    def Is_Coordenador(self):
        return self.coordenador
    def Set_Coordenador(self):
        if (self.coordenador):
            self.coordenador = False
        else:
            self.coordenador = True
    def Identificador(self):
        return self.identificador
    def SetIDcoord(self,id_coord):
        self.qualCoord = id_coord
    
    def Coord(self,_id):
        for d in enderecos_processos:
            d.SetIDcoord(_id)
    
    ### Simular parada de processo
    def Simular_erro(self):
        if (self.ativo):
            self.ativo = False
            print("O processo {} parou".format(self.identificador))
            
                       
        
    ### Verifica se o coordenador esta ativo
    def Verifica_coordenador(self):
        quant_coordenador = []
        for c in enderecos_processos:
            if (c.Is_Coordenador() and c.Is_Ativo()):
                quant_coordenador.append(enderecos_processos.index(c))
                
            elif (c.Is_Coordenador()):
                quant_coordenador.append(enderecos_processos.index(c))
       
            if (len(quant_coordenador) >= 2):
                enderecos_processos[quant_coordenador[1]].Set_Coordenador()
                enderecos_processos[quant_coordenador[0]].Coord(quant_coordenador[0]+1)
                quant_coordenador.pop(1)
                
    def Print(self):
        if (self.ativo):
            print("Identificador: {} , Coordenador: {} , Ativo: {} ".format(self.identificador,self.qualCoord, self.ativo))
        else:
            print("Processo: {} não respondendo".format(self.identificador))

# %%
criar_processos = int(input("Digite o numero de processos a serem criados: "))
chama_eleicao = list(map(int,input("Digite qual processo ira requisitar a eleição: ").split(' ')))
count = 1
enderecos_processos = []

while count <= criar_processos:
    if (count == criar_processos):
        p = Processo(count,True)
        enderecos_processos.append(p)
        p.Coord(count)
    else:
        p = Processo(count,False)  
        enderecos_processos.append(p)
        
    count+=1
# Out:
# Digite o numero de processos a serem criados: 40
# Digite qual processo ira requisitar a eleição: 0

# %%
print("Criando Processos \n")
for d in enderecos_processos:
    d.Print()
# Out:
# Criando Processos
#
# Identificador: 1 , Coordenador: 40 , Ativo: True
# Identificador: 2 , Coordenador: 40 , Ativo: True
# Identificador: 3 , Coordenador: 40 , Ativo: True
# Identificador: 4 , Coordenador: 40 , Ativo: True
# Identificador: 5 , Coordenador: 40 , Ativo: True
# Identificador: 6 , Coordenador: 40 , Ativo: True
# Identificador: 7 , Coordenador: 40 , Ativo: True
# Identificador: 8 , Coordenador: 40 , Ativo: True
# Identificador: 9 , Coordenador: 40 , Ativo: True
# Identificador: 10 , Coordenador: 40 , Ativo: True
# Identificador: 11 , Coordenador: 40 , Ativo: True
# Identificador: 12 , Coordenador: 40 , Ativo: True
# Identificador: 13 , Coordenador: 40 , Ativo: True
# Identificador: 14 , Coordenador: 40 , Ativo: True
# Identificador: 15 , Coordenador: 40 , Ativo: True
# Identificador: 16 , Coordenador: 40 , Ativo: True
# Identificador: 17 , Coordenador: 40 , Ativo: True
# Identificador: 18 , Coordenador: 40 , Ativo: True
# Identificador: 19 , Coordenador: 40 , Ativo: True
# Identificador: 20 , Coordenador: 40 , Ativo: True
# Identificador: 21 , Coordenador: 40 , Ativo: True
# Identificador: 22 , Coordenador: 40 , Ativo: True
# Identificador: 23 , Coordenador: 40 , Ativo: True
# Identificador: 24 , Coordenador: 40 , Ativo: True
# Identificador: 25 , Coordenador: 40 , Ativo: True
# Identificador: 26 , Coordenador: 40 , Ativo: True
# Identificador: 27 , Coordenador: 40 , Ativo: True
# Identificador: 28 , Coordenador: 40 , Ativo: True
# Identificador: 29 , Coordenador: 40 , Ativo: True
# Identificador: 30 , Coordenador: 40 , Ativo: True
# Identificador: 31 , Coordenador: 40 , Ativo: True
# Identificador: 32 , Coordenador: 40 , Ativo: True
# Identificador: 33 , Coordenador: 40 , Ativo: True
# Identificador: 34 , Coordenador: 40 , Ativo: True
# Identificador: 35 , Coordenador: 40 , Ativo: True
# Identificador: 36 , Coordenador: 40 , Ativo: True
# Identificador: 37 , Coordenador: 40 , Ativo: True
# Identificador: 38 , Coordenador: 40 , Ativo: True
# Identificador: 39 , Coordenador: 40 , Ativo: True
# Identificador: 40 , Coordenador: 40 , Ativo: True

# %%
print("\nSimulando Parada de Processos Aleatoriamente \n")
enderecos_processos[len(enderecos_processos)-1].Simular_erro() ## parando Coordenador
#enderecos_processos[18].Simular_erro() ## parando Coordenador

from random import randint
count2 = 0
while count2 < randint(0,len(enderecos_processos) // 2):
    enderecos_processos[randint(0,len(enderecos_processos)-1)].Simular_erro()
    count2 +=1
# Out:
# Simulando Parada de Processos Aleatoriamente
#
# O processo 40 parou
# O processo 2 parou
# O processo 13 parou
# O processo 6 parou
# O processo 39 parou
# O processo 22 parou

# %%
print("\nCoordenador e outros processos não estão respondendo\n")
for d in enderecos_processos:
    d.Print()
# Out:
# Coordenador e outros processos não estão respondendo
#
# Identificador: 1 , Coordenador: 40 , Ativo: True
# Processo: 2 não respondendo
# Identificador: 3 , Coordenador: 40 , Ativo: True
# Identificador: 4 , Coordenador: 40 , Ativo: True
# Identificador: 5 , Coordenador: 40 , Ativo: True
# Processo: 6 não respondendo
# Identificador: 7 , Coordenador: 40 , Ativo: True
# Identificador: 8 , Coordenador: 40 , Ativo: True
# Identificador: 9 , Coordenador: 40 , Ativo: True
# Identificador: 10 , Coordenador: 40 , Ativo: True
# Identificador: 11 , Coordenador: 40 , Ativo: True
# Identificador: 12 , Coordenador: 40 , Ativo: True
# Processo: 13 não respondendo
# Identificador: 14 , Coordenador: 40 , Ativo: True
# Identificador: 15 , Coordenador: 40 , Ativo: True
# Identificador: 16 , Coordenador: 40 , Ativo: True
# Identificador: 17 , Coordenador: 40 , Ativo: True
# Identificador: 18 , Coordenador: 40 , Ativo: True
# Identificador: 19 , Coordenador: 40 , Ativo: True
# Identificador: 20 , Coordenador: 40 , Ativo: True
# Identificador: 21 , Coordenador: 40 , Ativo: True
# Processo: 22 não respondendo
# Identificador: 23 , Coordenador: 40 , Ativo: True
# Identificador: 24 , Coordenador: 40 , Ativo: True
# Identificador: 25 , Coordenador: 40 , Ativo: True
# Identificador: 26 , Coordenador: 40 , Ativo: True
# Identificador: 27 , Coordenador: 40 , Ativo: True
# Identificador: 28 , Coordenador: 40 , Ativo: True
# Identificador: 29 , Coordenador: 40 , Ativo: True
# Identificador: 30 , Coordenador: 40 , Ativo: True
# Identificador: 31 , Coordenador: 40 , Ativo: True
# Identificador: 32 , Coordenador: 40 , Ativo: True
# Identificador: 33 , Coordenador: 40 , Ativo: True
# Identificador: 34 , Coordenador: 40 , Ativo: True
# Identificador: 35 , Coordenador: 40 , Ativo: True
# Identificador: 36 , Coordenador: 40 , Ativo: True
# Identificador: 37 , Coordenador: 40 , Ativo: True
# Identificador: 38 , Coordenador: 40 , Ativo: True
# Processo: 39 não respondendo
# Processo: 40 não respondendo

# %%
for e in chama_eleicao:
    print("\nProcesso {} Requisitando Eleição \n".format(e))
    enderecos_processos[e].Eleicao()
# Out:
# Processo 0 Requisitando Eleição
#
# O processo com ID: 1 saiu da eleição.
# O processo com ID: 3 saiu da eleição.
# O processo com ID: 4 saiu da eleição.
# O processo com ID: 5 saiu da eleição.
# O processo com ID: 7 saiu da eleição.
# O processo com ID: 8 saiu da eleição.
# O processo com ID: 9 saiu da eleição.
# O processo com ID: 10 saiu da eleição.
# O processo com ID: 11 saiu da eleição.
# O processo com ID: 12 saiu da eleição.
# O processo com ID: 14 saiu da eleição.
# O processo com ID: 15 saiu da eleição.
# O processo com ID: 16 saiu da eleição.
# O processo com ID: 17 saiu da eleição.
# O processo com ID: 18 saiu da eleição.
# O processo com ID: 19 saiu da eleição.
# O processo com ID: 20 saiu da eleição.
# O processo com ID: 21 saiu da eleição.
# O processo com ID: 23 saiu da eleição.
# O processo com ID: 24 saiu da eleição.
# O processo com ID: 25 saiu da eleição.
# O processo com ID: 26 saiu da eleição.
# O processo com ID: 27 saiu da eleição.
# O processo com ID: 28 saiu da eleição.
# O processo com ID: 29 saiu da eleição.
# O processo com ID: 30 saiu da eleição.
# O processo com ID: 31 saiu da eleição.
# O processo com ID: 32 saiu da eleição.
# O processo com ID: 33 saiu da eleição.
# O processo com ID: 34 saiu da eleição.
# O processo com ID: 35 saiu da eleição.
# O processo com ID: 36 saiu da eleição.
# O processo com ID: 37 saiu da eleição.
#
# O processo: 38 é o novo Coordenador(Valentão)

# %%
print("Processos após a escolha do novo coordenador(Valentão)\n")
for d in enderecos_processos:
    d.Print()
# Out:
# Processos após a escolha do novo coordenador(Valentão)
#
# Identificador: 1 , Coordenador: 38 , Ativo: True
# Processo: 2 não respondendo
# Identificador: 3 , Coordenador: 38 , Ativo: True
# Identificador: 4 , Coordenador: 38 , Ativo: True
# Identificador: 5 , Coordenador: 38 , Ativo: True
# Processo: 6 não respondendo
# Identificador: 7 , Coordenador: 38 , Ativo: True
# Identificador: 8 , Coordenador: 38 , Ativo: True
# Identificador: 9 , Coordenador: 38 , Ativo: True
# Identificador: 10 , Coordenador: 38 , Ativo: True
# Identificador: 11 , Coordenador: 38 , Ativo: True
# Identificador: 12 , Coordenador: 38 , Ativo: True
# Processo: 13 não respondendo
# Identificador: 14 , Coordenador: 38 , Ativo: True
# Identificador: 15 , Coordenador: 38 , Ativo: True
# Identificador: 16 , Coordenador: 38 , Ativo: True
# Identificador: 17 , Coordenador: 38 , Ativo: True
# Identificador: 18 , Coordenador: 38 , Ativo: True
# Identificador: 19 , Coordenador: 38 , Ativo: True
# Identificador: 20 , Coordenador: 38 , Ativo: True
# Identificador: 21 , Coordenador: 38 , Ativo: True
# Processo: 22 não respondendo
# Identificador: 23 , Coordenador: 38 , Ativo: True
# Identificador: 24 , Coordenador: 38 , Ativo: True
# Identificador: 25 , Coordenador: 38 , Ativo: True
# Identificador: 26 , Coordenador: 38 , Ativo: True
# Identificador: 27 , Coordenador: 38 , Ativo: True
# Identificador: 28 , Coordenador: 38 , Ativo: True
# Identificador: 29 , Coordenador: 38 , Ativo: True
# Identificador: 30 , Coordenador: 38 , Ativo: True
# Identificador: 31 , Coordenador: 38 , Ativo: True
# Identificador: 32 , Coordenador: 38 , Ativo: True
# Identificador: 33 , Coordenador: 38 , Ativo: True
# Identificador: 34 , Coordenador: 38 , Ativo: True
# Identificador: 35 , Coordenador: 38 , Ativo: True
# Identificador: 36 , Coordenador: 38 , Ativo: True
# Identificador: 37 , Coordenador: 38 , Ativo: True
# Identificador: 38 , Coordenador: 38 , Ativo: True
# Processo: 39 não respondendo
# Processo: 40 não respondendo
